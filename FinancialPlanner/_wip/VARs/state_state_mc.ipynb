# %%
using Revise
using StatsBase

# %%
includet("./SSVAR.jl")

# %%
Ψ = [3, 2]
Π = [.3 .2; .4 .5]
σ = [1, 1.5]
C = [1 .3 ;.3 1]

Σ = cor2cov(C, σ)

model = SSVAR(Ψ, Π, Σ)

initial_values = [2, 3]
T = 1
N = 100

scenarios = simulate(model, initial_values,  )
# Out:
# UndefVarError: `simulate` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\matsz\programowanie\Optymalizacja_portfela\FinancialPlanner\_wip\VARs\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:12
