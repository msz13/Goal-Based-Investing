# %%
using XLSX, DataFrames

# %%
DataFrame(XLSX.readtable("Poland.xlsx", "2022"))
# Out:
# 232×38 DataFrame
#  Row │ Reporter Name  Partner Name            Year     Trade Flow  Product Gro ⋯
#      │ Any            Any                     Any      Any         Any         ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Poland         Aruba                   2022     EXPIMP        All Produ ⋯
#    2 │ Poland         Afghanistan             2022     EXPIMP        All Produ
#    3 │ Poland         Angola                  2022     EXPIMP        All Produ
#    4 │ Poland         Anguila                 2022     EXPIMP        All Produ
#    5 │ Poland         Albania                 2022     EXPIMP        All Produ ⋯
#    6 │ Poland         Andorra                 2022     EXPIMP        All Produ
#    7 │ Poland         United Arab Emirates    2022     EXPIMP        All Produ
#    8 │ Poland         Argentina               2022     EXPIMP        All Produ
# ...

# %%
["United States", "Germany", "Japan"] in ["Germany", "Japan"]
# Out:
# false
